# %% [markdown]
# # Chapter 1: Hello World Agent with Strands
#
# This notebook shows how to build your first AI agent using the [Strands Agents SDK](https://github.com/strands-agents/sdk-python) powered by Amazon Bedrock.
#
# ### Prerequisites
# - AWS account with Amazon Bedrock access enabled
# - AWS credentials configured (`aws configure` or environment variables)
# - Bedrock model access enabled

# %% [markdown]
# ---
# ## Step 1: Install dependencies

# %%
# %pip install strands-agents -q
# Out:
# /home/agent/.venvs/ai-agents-ch1-5/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install strands-agents-tools -q
# Out:
# /home/agent/.venvs/ai-agents-ch1-5/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install uv matplotlib beautifulsoup4 pandas requests -q
# Out:
# /home/agent/.venvs/ai-agents-ch1-5/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## Step 2: Create your first agent

# %%
from strands import Agent

# Define the agent with a system prompt
agent = Agent()

# Interact with the agent
response = agent("Explain Amazon Bedrock Agents")
print(response)
# Out:
# # Amazon Bedrock Agents
#
# ## What is it?
#
# Amazon Bedrock Agents is a fully managed capability that enables **generative AI applications to execute multi-step tasks** by orchestrating interactions between foundation models (FMs), data sources, APIs, and other AWS services — without managing the underlying infrastructure.
#
# ---
#
# ## Core Concept
#
# ```
# User Request → Agent → Reasons & Plans → Takes Actions → Returns Response
# ```
#
# Agents use a **ReAct (Reasoning + Acting)** framework where the FM:
# 1. **Reasons** about what needs to be done
# 2. **Plans** the steps
# 3. **Acts** by calling tools/APIs
# 4. **Observes** results
# 5. **Iterates** until the task is complete
#
# ---
#
# ## Key Components
#
# ### 1. **Foundation Model**
# - The "brain" of the agent
# - Supports Claude, Titan, Llama, etc.
# - Handles reasoning and decision-making
#
# ### 2. **Instructions**
# ```
# "You are a customer service agent for Acme Corp.
# Help users track orders, process returns, and
# answer product questions. Always be professional."
# ```
# - System prompt defining agent behavior, persona, and constraints
#
# ### 3. **Action Groups**
# The agent's ability to **DO things**:
#
# ```
# Action Group: OrderManagement
# ├── getOrderStatus(orderId)
# ├── cancelOrder(orderId, reason)
# └── updateShippingAddress(orderId, address)
# ```
#
# - Backed by **AWS Lambda functions**
# - Defined via **OpenAPI schemas**
# - Tells the agent WHAT actions exist and WHEN to use them
#
# ### 4. **Knowledge Bases**
# The agent's ability to **KNOW things**:
#
# ```
# Knowledge Base
# ├── Product Documentation (PDFs)
# ├── FAQs
# ├── Policy Documents
# └── → Stored in Vector DB (OpenSearch, Pinecone, etc.)
# ```
#
# - Uses **RAG (Retrieval-Augmented Generation)**
# - Agent queries relevant documents automatically
# - Reduces hallucinations with grounded responses
#
# ### 5. **Memory**
# - **Session memory** — remembers context within a conversation
# - **Long-term memory** — retains information across sessions (user preferences, history)
#
# ### 6. **Guardrails**
# - Content filtering
# - PII redaction
# - Topic restrictions
# - Prevents harmful or off-topic responses
#
# ---
#
# ## How It Works — Step by Step
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │                    AGENT LOOP                        │
# │                                                      │
# │  User: "What's the status of order #12345           │
# │         and when will it arrive?"                    │
# │                      │                              │
# │                       ▼                             │
# │            [Foundation Model Reasons]               │
# │        "I need to call getOrderStatus(12345)"       │
# │                       │                             │
# │                       ▼                             │
# │            [Calls Lambda Function]                  │
# │         → Returns: "Shipped, arriving Dec 5"        │
# │                       │                             │
# │                       ▼                             │
# │            [Model Synthesizes Response]             │
# │   "Your order #12345 has shipped and will          │
# │    arrive on December 5th!"                         │
# └─────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## Architecture Diagram
#
# ```
#                     ┌──────────────┐
#                     │     User     │
#                     └──────┬───────┘
#                            │
#                     ┌──────▼───────┐
#                     │   Bedrock    │
#                     │    Agent     │
#                     └──────┬───────┘
#                            │
#           ┌────────────────┼────────────────┐
#           │                │                │
#    ┌──────▼──────┐  ┌──────▼──────┐  ┌─────▼───────┐
#    │  Foundation  │  │   Action    │  │  Knowledge  │
#    │    Model     │  │   Groups    │  │    Base     │
#    │  (Claude,    │  │  (Lambda)   │  │  (RAG/S3)  │
#    │  Titan, etc) │  └──────┬──────┘  └─────┬───────┘
#    └─────────────┘         │               │
#                     ┌──────▼──────┐  ┌──────▼──────┐
#                     │  External   │  │  Vector DB  │
#                     │    APIs/    │  │ (OpenSearch │
#                     │  Databases  │  │  Pinecone)  │
#                     └─────────────┘  └─────────────┘
# ```
#
# ---
#
# ## Real-World Use Cases
#
# | Use Case | Actions | Knowledge Base |
# |----------|---------|----------------|
# | **Customer Service Bot** | Check orders, process refunds | FAQs, policies |
# | **HR Assistant** | Submit PTO, update info | Employee handbook |
# | **IT Help Desk** | Reset passwords, create tickets | Runbooks, docs |
# | **Financial Advisor** | Pull account data, execute trades | Market research |
# | **Code Assistant** | Run tests, deploy code | Documentation |
# | **Healthcare Bot** | Schedule appointments | Medical guidelines |
#
# ---
#
# ## Code Example — Creating an Agent (Python/Boto3)
#
# ```python
# import boto3
#
# client = boto3.client('bedrock-agent')
#
# # Create an Agent
# response = client.create_agent(
#     agentName='CustomerServiceAgent',
#     agentResourceRoleArn='arn:aws:iam::123456789:role/BedrockAgentRole',
#     foundationModel='anthropic.claude-3-sonnet-20240229-v1:0',
#     instruction="""
#         You are a helpful customer service agent for Acme Corp.
#         Help customers with orders, returns, and product questions.
#         Always verify customer identity before sharing order details.
#         Be concise, friendly, and professional.
#     """,
#     description='Customer service agent for order management'
# )
#
# agent_id = response['agent']['agentId']
# ```
#
# ```python
# # Create an Action Group
# action_group = client.create_agent_action_group(
#     agentId=agent_id,
#     agentVersion='DRAFT',
#     actionGroupName='OrderManagement',
#     actionGroupExecutor={
#         'lambda': 'arn:aws:lambda:us-east-1:123456789:function:OrderHandler'
#     },
#     apiSchema={
#         's3': {
#             's3BucketName': 'my-schemas-bucket',
#             's3ObjectKey': 'order-management-schema.json'
#         }
#     },
#     description='Actions for managing customer orders'
# )
# ```
#
# ```python
# # Invoke the Agent
# runtime_client = boto3.client('bedrock-agent-runtime')
#
# response = runtime_client.invoke_agent(
#     agentId=agent_id,
#     agentAliasId='TSTALIASID',
#     sessionId='user-session-123',
#     inputText='What is the status of my order #98765?'
# )
#
# # Stream the response
# for event in response['completion']:
#     if 'chunk' in event:
#         print(event['chunk']['bytes'].decode(), end='')
# ```
#
# ---
#
# ## OpenAPI Schema Example (Action Definition)
#
# ```json
# {
#   "openapi": "3.0.0",
#   "info": {
#     "title": "Order Management API",
#     "version": "1.0.0"
#   },
#   "paths": {
#     "/orders/{orderId}": {
#       "get": {
#         "summary": "Get order status",
#         "description": "Retrieves the current status and details of an order",
#         "operationId": "getOrderStatus",
#         "parameters": [
#           {
#             "name": "orderId",
#             "in": "path",
#             "required": true,
#             "description": "The unique order identifier",
#             "schema": { "type": "string" }
#           }
#         ],
#         "responses": {
#           "200": {
#             "description": "Order details",
#             "content": {
#               "application/json": {
#                 "schema": {
#                   "type": "object",
#                   "properties": {
#                     "status": { "type": "string" },
#                     "estimatedDelivery": { "type": "string" },
#                     "trackingNumber": { "type": "string" }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# ```
#
# ---
#
# ## Advanced Features
#
# ### Multi-Agent Collaboration
# ```
# Supervisor Agent
# ├── Research Agent    (gathers information)
# ├── Analysis Agent    (processes data)
# └── Writing Agent     (generates reports)
# ```
# - Agents can invoke other agents
# - Enables complex, parallel workflows
#
# ### Inline Agents
# - Create agents **dynamically at runtime**
# - No pre-configuration needed
# - Useful for highly customized, per-user experiences
#
# ### Code Interpretation
# - Agent can **write and execute code**
# - Useful for data analysis, math, file processing
#
# ### Return of Control
# - Agent pauses and returns control to your application
# - Application handles the action, returns result
# - More control over sensitive operations
#
# ---
#
# ## Prompt Customization
#
# Bedrock Agents uses a **multi-step prompt pipeline**:
#
# ```
# 1. Pre-processing prompt    → Validates/categorizes user input
# 2. Orchestration prompt     → Reasons and plans actions
# 3. Knowledge Base prompt    → Formats KB queries/responses
# 4. Post-processing prompt   → Formats final response
# ```
#
# Each can be customized or replaced entirely.
#
# ---
#
# ## Key Benefits
#
# | Benefit | Description |
# |---------|-------------|
# | **Fully Managed** | No infrastructure to manage |
# | **Serverless** | Pay per invocation |
# | **Secure** | IAM, VPC, encryption built-in |
# | **Auditable** | CloudTrail logging of all actions |
# | **Flexible** | Swap FMs without changing code |
# | **Integrated** | Native AWS service integrations |
#
# ---
#
# ## Pricing
#
# - Charged based on:
#   - **Input/output tokens** processed by the FM
#   - **Knowledge Base** retrieval and storage
#   - **Lambda invocations** for action groups
# - No charge for the agent orchestration layer itself
#
# ---
#
# ## Limitations to Consider
#
# - ⚠️ **Latency** — multi-step reasoning takes time
# - ⚠️ **Cost** — multiple FM calls per request adds up
# - ⚠️ **Context window limits** — long conversations may truncate
# - ⚠️ **Determinism** — outputs aren't always predictable
# - ⚠️ **Debugging** — can be complex to trace agent decisions
#
# ---
#
# ## When to Use Bedrock Agents vs. Alternatives
#
# | Scenario | Recommendation |
# |----------|---------------|
# | Multi-step task automation | ✅ Bedrock Agents |
# | Simple Q&A chatbot | Consider Bedrock + KB only |
# | Real-time, low-latency needed | ⚠️ Evaluate carefully |
# | Complex agentic workflows | ✅ Multi-agent setup |
# | Highly custom orchestration | Consider LangChain/custom |
#
# ---
#
# Amazon Bedrock Agents essentially lets you build **autonomous AI workflows** that can reason, retrieve information, and take actions — all within a secure, managed AWS environment.# Amazon Bedrock Agents
#
# ## What is it?
#
# Amazon Bedrock Agents is a fully managed capability that enables **generative AI applications to execute multi-step tasks** by orchestrating interactions between foundation models (FMs), data sources, APIs, and other AWS services — without managing the underlying infrastructure.
#
# ---
#
# ## Core Concept
#
# ```
# User Request → Agent → Reasons & Plans → Takes Actions → Returns Response
# ```
#
# Agents use a **ReAct (Reasoning + Acting)** framework where the FM:
# 1. **Reasons** about what needs to be done
# 2. **Plans** the steps
# 3. **Acts** by calling tools/APIs
# 4. **Observes** results
# 5. **Iterates** until the task is complete
#
# ---
#
# ## Key Components
#
# ### 1. **Foundation Model**
# - The "brain" of the agent
# - Supports Claude, Titan, Llama, etc.
# - Handles reasoning and decision-making
#
# ### 2. **Instructions**
# ```
# "You are a customer service agent for Acme Corp.
# Help users track orders, process returns, and
# answer product questions. Always be professional."
# ```
# - System prompt defining agent behavior, persona, and constraints
#
# ### 3. **Action Groups**
# The agent's ability to **DO things**:
#
# ```
# Action Group: OrderManagement
# ├── getOrderStatus(orderId)
# ├── cancelOrder(orderId, reason)
# └── updateShippingAddress(orderId, address)
# ```
#
# - Backed by **AWS Lambda functions**
# - Defined via **OpenAPI schemas**
# - Tells the agent WHAT actions exist and WHEN to use them
#
# ### 4. **Knowledge Bases**
# The agent's ability to **KNOW things**:
#
# ```
# Knowledge Base
# ├── Product Documentation (PDFs)
# ├── FAQs
# ├── Policy Documents
# └── → Stored in Vector DB (OpenSearch, Pinecone, etc.)
# ```
#
# - Uses **RAG (Retrieval-Augmented Generation)**
# - Agent queries relevant documents automatically
# - Reduces hallucinations with grounded responses
#
# ### 5. **Memory**
# - **Session memory** — remembers context within a conversation
# - **Long-term memory** — retains information across sessions (user preferences, history)
#
# ### 6. **Guardrails**
# - Content filtering
# - PII redaction
# - Topic restrictions
# - Prevents harmful or off-topic responses
#
# ---
#
# ## How It Works — Step by Step
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │                    AGENT LOOP                        │
# │                                                      │
# │  User: "What's the status of order #12345           │
# │         and when will it arrive?"                    │
# │                      │                              │
# │                       ▼                             │
# │            [Foundation Model Reasons]               │
# │        "I need to call getOrderStatus(12345)"       │
# │                       │                             │
# │                       ▼                             │
# │            [Calls Lambda Function]                  │
# │         → Returns: "Shipped, arriving Dec 5"        │
# │                       │                             │
# │                       ▼                             │
# │            [Model Synthesizes Response]             │
# │   "Your order #12345 has shipped and will          │
# │    arrive on December 5th!"                         │
# └─────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## Architecture Diagram
#
# ```
#                     ┌──────────────┐
#                     │     User     │
#                     └──────┬───────┘
#                            │
#                     ┌──────▼───────┐
#                     │   Bedrock    │
#                     │    Agent     │
#                     └──────┬───────┘
#                            │
#           ┌────────────────┼────────────────┐
#           │                │                │
#    ┌──────▼──────┐  ┌──────▼──────┐  ┌─────▼───────┐
#    │  Foundation  │  │   Action    │  │  Knowledge  │
#    │    Model     │  │   Groups    │  │    Base     │
#    │  (Claude,    │  │  (Lambda)   │  │  (RAG/S3)  │
#    │  Titan, etc) │  └──────┬──────┘  └─────┬───────┘
#    └─────────────┘         │               │
#                     ┌──────▼──────┐  ┌──────▼──────┐
#                     │  External   │  │  Vector DB  │
#                     │    APIs/    │  │ (OpenSearch │
#                     │  Databases  │  │  Pinecone)  │
#                     └─────────────┘  └─────────────┘
# ```
#
# ---
#
# ## Real-World Use Cases
#
# | Use Case | Actions | Knowledge Base |
# |----------|---------|----------------|
# | **Customer Service Bot** | Check orders, process refunds | FAQs, policies |
# | **HR Assistant** | Submit PTO, update info | Employee handbook |
# | **IT Help Desk** | Reset passwords, create tickets | Runbooks, docs |
# | **Financial Advisor** | Pull account data, execute trades | Market research |
# | **Code Assistant** | Run tests, deploy code | Documentation |
# | **Healthcare Bot** | Schedule appointments | Medical guidelines |
#
# ---
#
# ## Code Example — Creating an Agent (Python/Boto3)
#
# ```python
# import boto3
#
# client = boto3.client('bedrock-agent')
#
# # Create an Agent
# response = client.create_agent(
#     agentName='CustomerServiceAgent',
#     agentResourceRoleArn='arn:aws:iam::123456789:role/BedrockAgentRole',
#     foundationModel='anthropic.claude-3-sonnet-20240229-v1:0',
#     instruction="""
#         You are a helpful customer service agent for Acme Corp.
#         Help customers with orders, returns, and product questions.
#         Always verify customer identity before sharing order details.
#         Be concise, friendly, and professional.
#     """,
#     description='Customer service agent for order management'
# )
#
# agent_id = response['agent']['agentId']
# ```
#
# ```python
# # Create an Action Group
# action_group = client.create_agent_action_group(
#     agentId=agent_id,
#     agentVersion='DRAFT',
#     actionGroupName='OrderManagement',
#     actionGroupExecutor={
#         'lambda': 'arn:aws:lambda:us-east-1:123456789:function:OrderHandler'
#     },
#     apiSchema={
#         's3': {
#             's3BucketName': 'my-schemas-bucket',
#             's3ObjectKey': 'order-management-schema.json'
#         }
#     },
#     description='Actions for managing customer orders'
# )
# ```
#
# ```python
# # Invoke the Agent
# runtime_client = boto3.client('bedrock-agent-runtime')
#
# response = runtime_client.invoke_agent(
#     agentId=agent_id,
#     agentAliasId='TSTALIASID',
#     sessionId='user-session-123',
#     inputText='What is the status of my order #98765?'
# )
#
# # Stream the response
# for event in response['completion']:
#     if 'chunk' in event:
#         print(event['chunk']['bytes'].decode(), end='')
# ```
#
# ---
#
# ## OpenAPI Schema Example (Action Definition)
#
# ```json
# {
#   "openapi": "3.0.0",
#   "info": {
#     "title": "Order Management API",
#     "version": "1.0.0"
#   },
#   "paths": {
#     "/orders/{orderId}": {
#       "get": {
#         "summary": "Get order status",
#         "description": "Retrieves the current status and details of an order",
#         "operationId": "getOrderStatus",
#         "parameters": [
#           {
#             "name": "orderId",
#             "in": "path",
#             "required": true,
#             "description": "The unique order identifier",
#             "schema": { "type": "string" }
#           }
#         ],
#         "responses": {
#           "200": {
#             "description": "Order details",
#             "content": {
#               "application/json": {
#                 "schema": {
#                   "type": "object",
#                   "properties": {
#                     "status": { "type": "string" },
#                     "estimatedDelivery": { "type": "string" },
#                     "trackingNumber": { "type": "string" }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# ```
#
# ---
#
# ## Advanced Features
#
# ### Multi-Agent Collaboration
# ```
# Supervisor Agent
# ├── Research Agent    (gathers information)
# ├── Analysis Agent    (processes data)
# └── Writing Agent     (generates reports)
# ```
# - Agents can invoke other agents
# - Enables complex, parallel workflows
#
# ### Inline Agents
# - Create agents **dynamically at runtime**
# - No pre-configuration needed
# - Useful for highly customized, per-user experiences
#
# ### Code Interpretation
# - Agent can **write and execute code**
# - Useful for data analysis, math, file processing
#
# ### Return of Control
# - Agent pauses and returns control to your application
# - Application handles the action, returns result
# - More control over sensitive operations
#
# ---
#
# ## Prompt Customization
#
# Bedrock Agents uses a **multi-step prompt pipeline**:
#
# ```
# 1. Pre-processing prompt    → Validates/categorizes user input
# 2. Orchestration prompt     → Reasons and plans actions
# 3. Knowledge Base prompt    → Formats KB queries/responses
# 4. Post-processing prompt   → Formats final response
# ```
#
# Each can be customized or replaced entirely.
#
# ---
#
# ## Key Benefits
#
# | Benefit | Description |
# |---------|-------------|
# | **Fully Managed** | No infrastructure to manage |
# | **Serverless** | Pay per invocation |
# | **Secure** | IAM, VPC, encryption built-in |
# | **Auditable** | CloudTrail logging of all actions |
# | **Flexible** | Swap FMs without changing code |
# | **Integrated** | Native AWS service integrations |
#
# ---
#
# ## Pricing
#
# - Charged based on:
#   - **Input/output tokens** processed by the FM
#   - **Knowledge Base** retrieval and storage
#   - **Lambda invocations** for action groups
# - No charge for the agent orchestration layer itself
#
# ---
#
# ## Limitations to Consider
#
# - ⚠️ **Latency** — multi-step reasoning takes time
# - ⚠️ **Cost** — multiple FM calls per request adds up
# - ⚠️ **Context window limits** — long conversations may truncate
# - ⚠️ **Determinism** — outputs aren't always predictable
# - ⚠️ **Debugging** — can be complex to trace agent decisions
#
# ---
#
# ## When to Use Bedrock Agents vs. Alternatives
#
# | Scenario | Recommendation |
# |----------|---------------|
# | Multi-step task automation | ✅ Bedrock Agents |
# | Simple Q&A chatbot | Consider Bedrock + KB only |
# | Real-time, low-latency needed | ⚠️ Evaluate carefully |
# | Complex agentic workflows | ✅ Multi-agent setup |
# | Highly custom orchestration | Consider LangChain/custom |
#
# ---
#
# Amazon Bedrock Agents essentially lets you build **autonomous AI workflows** that can reason, retrieve information, and take actions — all within a secure, managed AWS environment.
