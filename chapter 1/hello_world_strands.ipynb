# %% [markdown]
# # Chapter 1: Hello World Agent with Strands
#
# This notebook shows how to build your first AI agent using the [Strands Agents SDK](https://github.com/strands-agents/sdk-python) powered by Amazon Bedrock.
#
# ### Prerequisites
# - AWS account with Amazon Bedrock access enabled
# - AWS credentials configured (`aws configure` or environment variables)
# - Bedrock model access enabled

# %% [markdown]
# ---
# ## Step 1: Install dependencies

# %%
# %pip install strands-agents -q
# Out:
# /home/agent/.venvs/ai-agents-ch1-5/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install strands-agents-tools -q
# Out:
# /home/agent/.venvs/ai-agents-ch1-5/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install uv matplotlib beautifulsoup4 pandas requests -q
# Out:
# /home/agent/.venvs/ai-agents-ch1-5/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## Step 2: Create your first agent

# %%
from strands import Agent

# Define the agent with a system prompt
agent = Agent()

# Interact with the agent
response = agent("Explain Amazon Bedrock Agents")
print(response)
# Out:
# # Amazon Bedrock Agents
#
# ## What is it?
#
# Amazon Bedrock Agents is a fully managed capability that enables you to build **autonomous AI agents** that can execute multi-step tasks by combining foundation models (FMs) with external tools, APIs, and data sources — without managing the underlying infrastructure.
#
# ---
#
# ## Core Concept
#
# ```
# User Request → Agent → Reasons & Plans → Takes Actions → Returns Response
#                 ↑              ↓
#            Foundation      Tool/API
#              Model          Calls
# ```
#
# Agents use a **ReAct (Reasoning + Acting)** pattern:
# 1. **Reason** about what needs to be done
# 2. **Act** by calling tools or APIs
# 3. **Observe** the results
# 4. **Repeat** until the task is complete
#
# ---
#
# ## Key Components
#
# ### 1. **Foundation Model**
# - The "brain" of the agent
# - Supported models: Claude (Anthropic), Titan, Llama, etc.
# - Handles reasoning, planning, and response generation
#
# ### 2. **Instructions (System Prompt)**
# ```
# "You are a customer service agent for Acme Corp.
# Help users with order inquiries, returns, and
# product questions. Always be polite and professional."
# ```
#
# ### 3. **Action Groups**
# The tools/actions the agent can perform:
#
# ```
# Action Group: OrderManagement
# ├── getOrderStatus(orderId)
# ├── cancelOrder(orderId)
# ├── updateShippingAddress(orderId, address)
# └── initiateReturn(orderId, reason)
# ```
#
# Defined via:
# - **OpenAPI schema** (for REST APIs)
# - **AWS Lambda functions**
# - **Built-in capabilities**
#
# ### 4. **Knowledge Bases** *(Optional)*
# - Connects agent to your documents/data
# - Uses RAG (Retrieval Augmented Generation)
# - Sources: S3, Confluence, SharePoint, web pages
# - Enables answers grounded in your specific data
#
# ### 5. **Memory** *(Optional)*
# - Retains context across multiple conversations
# - Short-term: within a session
# - Long-term: across sessions
#
# ### 6. **Guardrails** *(Optional)*
# - Content filtering
# - PII detection/redaction
# - Topic restrictions
# - Prevents harmful outputs
#
# ---
#
# ## How It Works — Step by Step
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │                    Agent Execution                   │
# │                                                      │
# │  1. User: "What's the status of order #12345?"      │
# │                    ↓                                 │
# │  2. Agent reasons: "I need to call getOrderStatus"  │
# │                    ↓                                 │
# │  3. Calls Lambda: getOrderStatus("12345")           │
# │                    ↓                                 │
# │  4. Lambda returns: {status: "shipped", ETA: "Dec5"}│
# │                    ↓                                 │
# │  5. Agent responds: "Your order #12345 has shipped  │
# │     and will arrive by December 5th!"               │
# └─────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## Architecture Overview
#
# ```
#                     ┌──────────────────┐
#                     │   Your App/UI    │
#                     └────────┬─────────┘
#                              │ API Call
#                     ┌────────▼─────────┐
#                     │  Bedrock Agent   │
#                     │  ┌────────────┐  │
#                     │  │Foundation  │  │
#                     │  │  Model     │  │
#                     │  └────────────┘  │
#                     └──┬───────────┬───┘
#                        │           │
#            ┌───────────▼──┐  ┌─────▼──────────┐
#            │ Action Groups│  │ Knowledge Base  │
#            │  (Lambdas /  │  │  (Vector Store) │
#            │    APIs)     │  │                 │
#            └──────┬───────┘  └─────────────────┘
#                   │
#         ┌─────────▼──────────┐
#         │  External Systems  │
#         │  • Databases       │
#         │  • REST APIs       │
#         │  • AWS Services    │
#         │  • SaaS Tools      │
#         └────────────────────┘
# ```
#
# ---
#
# ## Setting Up an Agent — Key Steps
#
# ### Step 1: Create the Agent
# ```python
# import boto3
#
# bedrock_agent = boto3.client('bedrock-agent')
#
# response = bedrock_agent.create_agent(
#     agentName='CustomerServiceAgent',
#     foundationModel='anthropic.claude-3-sonnet-20240229-v1:0',
#     instruction="""You are a helpful customer service agent.
#     Use available tools to help customers with their requests.""",
#     agentResourceRoleArn='arn:aws:iam::123456789:role/BedrockAgentRole'
# )
# ```
#
# ### Step 2: Define Action Group with OpenAPI Schema
# ```yaml
# openapi: "3.0.0"
# info:
#   title: Order API
#   version: "1.0"
# paths:
#   /orders/{orderId}:
#     get:
#       summary: Get order status
#       operationId: getOrderStatus
#       parameters:
#         - name: orderId
#           in: path
#           required: true
#           schema:
#             type: string
#       responses:
#         "200":
#           description: Order details
# ```
#
# ### Step 3: Create Lambda Function
# ```python
# def lambda_handler(event, context):
#     action = event['actionGroup']
#     api_path = event['apiPath']
#     parameters = event['parameters']
#
#     if api_path == '/orders/{orderId}':
#         order_id = next(p['value'] for p in parameters
#                        if p['name'] == 'orderId')
#         # Fetch from database
#         order = get_order_from_db(order_id)
#
#         return {
#             "messageVersion": "1.0",
#             "response": {
#                 "actionGroup": action,
#                 "apiPath": api_path,
#                 "httpStatusCode": 200,
#                 "responseBody": {
#                     "application/json": {
#                         "body": json.dumps(order)
#                     }
#                 }
#             }
#         }
# ```
#
# ### Step 4: Invoke the Agent
# ```python
# bedrock_runtime = boto3.client('bedrock-agent-runtime')
#
# response = bedrock_runtime.invoke_agent(
#     agentId='AGENT_ID',
#     agentAliasId='ALIAS_ID',
#     sessionId='unique-session-123',
#     inputText='What is the status of order #12345?'
# )
#
# # Stream the response
# for event in response['completion']:
#     if 'chunk' in event:
#         print(event['chunk']['bytes'].decode())
# ```
#
# ---
#
# ## Agent Collaboration (Multi-Agent)
#
# Bedrock supports **multi-agent architectures**:
#
# ```
#                 ┌─────────────────┐
#                 │ Supervisor Agent │
#                 │  (Orchestrator)  │
#                 └────────┬────────┘
#                          │
#           ┌──────────────┼──────────────┐
#           │              │              │
#    ┌──────▼──────┐ ┌─────▼──────┐ ┌───▼────────┐
#    │  Research   │ │  Writing   │ │   Review   │
#    │   Agent     │ │   Agent    │ │   Agent    │
#    └─────────────┘ └────────────┘ └────────────┘
# ```
#
# ---
#
# ## Inline Agents
#
# Create **ephemeral agents on-the-fly** without pre-configuration:
#
# ```python
# response = bedrock_runtime.invoke_inline_agent(
#     foundationModel='anthropic.claude-3-sonnet-20240229-v1:0',
#     instruction='You are a data analysis assistant.',
#     actionGroups=[{
#         'actionGroupName': 'DataTools',
#         'actionGroupExecutor': {
#             'lambda': 'arn:aws:lambda:...'
#         }
#     }],
#     inputText='Analyze the sales data for Q4'
# )
# ```
#
# ---
#
# ## Built-in Capabilities
#
# | Capability | Description |
# |-----------|-------------|
# | **Code Interpreter** | Execute Python code dynamically |
# | **User Confirmation** | Pause and ask user before actions |
# | **Return of Control** | Send action back to your app to handle |
# | **Session Attributes** | Pass metadata throughout conversation |
#
# ---
#
# ## Common Use Cases
#
# | Use Case | Description |
# |----------|-------------|
# | **Customer Service** | Handle inquiries, orders, returns |
# | **IT Operations** | Automate incident response, ticketing |
# | **Data Analysis** | Query databases, generate reports |
# | **HR Assistant** | Answer policy questions, manage requests |
# | **DevOps Automation** | Deploy code, manage infrastructure |
# | **Research Assistant** | Gather, summarize, analyze information |
# | **Financial Analysis** | Process transactions, generate insights |
#
# ---
#
# ## Pricing Considerations
#
# ```
# Cost = FM Input Tokens + FM Output Tokens + AWS Service Calls
#
#        └── Per 1K tokens    └── Lambda, S3, OpenSearch, etc.
# ```
#
# - **No agent-specific fee** — pay for FM usage + underlying services
# - Knowledge Base adds **OpenSearch Serverless** or other vector DB costs
# - Lambda invocations billed normally
#
# ---
#
# ## Best Practices
#
# ### ✅ Do's
# - Write **clear, specific instructions** — quality matters greatly
# - **Break complex tasks** into smaller action groups
# - Use **guardrails** in production
# - **Test with diverse inputs** before deploying
# - Implement **proper error handling** in Lambda functions
# - Use **aliases** for versioning and deployment control
#
# ### ❌ Don'ts
# - Don't give agents **more permissions than needed** (least privilege)
# - Avoid **vague instructions** — be explicit about behavior
# - Don't skip **input validation** in your Lambda functions
# - Avoid exposing **sensitive data** without guardrails
#
# ---
#
# ## Comparison with Other Approaches
#
# | Feature | Bedrock Agents | DIY LangChain/LlamaIndex |
# |---------|---------------|--------------------------|
# | Setup | Managed, low-code | Custom code required |
# | Scaling | Automatic | Self-managed |
# | Maintenance | AWS managed | You manage |
# | Flexibility | Moderate | High |
# | Cost | Pay-per-use | Infrastructure costs |
# | Debugging | AWS Console + CloudWatch | Custom logging |
#
# ---
#
# ## Summary
#
# ```
# Amazon Bedrock Agents =
#     Foundation Model (Reasoning)
#     + Action Groups (Doing)
#     + Knowledge Bases (Knowing)
#     + Memory (Remembering)
#     + Guardrails (Safety)
#     = Autonomous AI Agent
# ```
#
# Bedrock Agents is ideal when you need AI that can **take actions**, not just generate text — automating complex workflows while staying within AWS's managed, secure environment.# Amazon Bedrock Agents
#
# ## What is it?
#
# Amazon Bedrock Agents is a fully managed capability that enables you to build **autonomous AI agents** that can execute multi-step tasks by combining foundation models (FMs) with external tools, APIs, and data sources — without managing the underlying infrastructure.
#
# ---
#
# ## Core Concept
#
# ```
# User Request → Agent → Reasons & Plans → Takes Actions → Returns Response
#                 ↑              ↓
#            Foundation      Tool/API
#              Model          Calls
# ```
#
# Agents use a **ReAct (Reasoning + Acting)** pattern:
# 1. **Reason** about what needs to be done
# 2. **Act** by calling tools or APIs
# 3. **Observe** the results
# 4. **Repeat** until the task is complete
#
# ---
#
# ## Key Components
#
# ### 1. **Foundation Model**
# - The "brain" of the agent
# - Supported models: Claude (Anthropic), Titan, Llama, etc.
# - Handles reasoning, planning, and response generation
#
# ### 2. **Instructions (System Prompt)**
# ```
# "You are a customer service agent for Acme Corp.
# Help users with order inquiries, returns, and
# product questions. Always be polite and professional."
# ```
#
# ### 3. **Action Groups**
# The tools/actions the agent can perform:
#
# ```
# Action Group: OrderManagement
# ├── getOrderStatus(orderId)
# ├── cancelOrder(orderId)
# ├── updateShippingAddress(orderId, address)
# └── initiateReturn(orderId, reason)
# ```
#
# Defined via:
# - **OpenAPI schema** (for REST APIs)
# - **AWS Lambda functions**
# - **Built-in capabilities**
#
# ### 4. **Knowledge Bases** *(Optional)*
# - Connects agent to your documents/data
# - Uses RAG (Retrieval Augmented Generation)
# - Sources: S3, Confluence, SharePoint, web pages
# - Enables answers grounded in your specific data
#
# ### 5. **Memory** *(Optional)*
# - Retains context across multiple conversations
# - Short-term: within a session
# - Long-term: across sessions
#
# ### 6. **Guardrails** *(Optional)*
# - Content filtering
# - PII detection/redaction
# - Topic restrictions
# - Prevents harmful outputs
#
# ---
#
# ## How It Works — Step by Step
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │                    Agent Execution                   │
# │                                                      │
# │  1. User: "What's the status of order #12345?"      │
# │                    ↓                                 │
# │  2. Agent reasons: "I need to call getOrderStatus"  │
# │                    ↓                                 │
# │  3. Calls Lambda: getOrderStatus("12345")           │
# │                    ↓                                 │
# │  4. Lambda returns: {status: "shipped", ETA: "Dec5"}│
# │                    ↓                                 │
# │  5. Agent responds: "Your order #12345 has shipped  │
# │     and will arrive by December 5th!"               │
# └─────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## Architecture Overview
#
# ```
#                     ┌──────────────────┐
#                     │   Your App/UI    │
#                     └────────┬─────────┘
#                              │ API Call
#                     ┌────────▼─────────┐
#                     │  Bedrock Agent   │
#                     │  ┌────────────┐  │
#                     │  │Foundation  │  │
#                     │  │  Model     │  │
#                     │  └────────────┘  │
#                     └──┬───────────┬───┘
#                        │           │
#            ┌───────────▼──┐  ┌─────▼──────────┐
#            │ Action Groups│  │ Knowledge Base  │
#            │  (Lambdas /  │  │  (Vector Store) │
#            │    APIs)     │  │                 │
#            └──────┬───────┘  └─────────────────┘
#                   │
#         ┌─────────▼──────────┐
#         │  External Systems  │
#         │  • Databases       │
#         │  • REST APIs       │
#         │  • AWS Services    │
#         │  • SaaS Tools      │
#         └────────────────────┘
# ```
#
# ---
#
# ## Setting Up an Agent — Key Steps
#
# ### Step 1: Create the Agent
# ```python
# import boto3
#
# bedrock_agent = boto3.client('bedrock-agent')
#
# response = bedrock_agent.create_agent(
#     agentName='CustomerServiceAgent',
#     foundationModel='anthropic.claude-3-sonnet-20240229-v1:0',
#     instruction="""You are a helpful customer service agent.
#     Use available tools to help customers with their requests.""",
#     agentResourceRoleArn='arn:aws:iam::123456789:role/BedrockAgentRole'
# )
# ```
#
# ### Step 2: Define Action Group with OpenAPI Schema
# ```yaml
# openapi: "3.0.0"
# info:
#   title: Order API
#   version: "1.0"
# paths:
#   /orders/{orderId}:
#     get:
#       summary: Get order status
#       operationId: getOrderStatus
#       parameters:
#         - name: orderId
#           in: path
#           required: true
#           schema:
#             type: string
#       responses:
#         "200":
#           description: Order details
# ```
#
# ### Step 3: Create Lambda Function
# ```python
# def lambda_handler(event, context):
#     action = event['actionGroup']
#     api_path = event['apiPath']
#     parameters = event['parameters']
#
#     if api_path == '/orders/{orderId}':
#         order_id = next(p['value'] for p in parameters
#                        if p['name'] == 'orderId')
#         # Fetch from database
#         order = get_order_from_db(order_id)
#
#         return {
#             "messageVersion": "1.0",
#             "response": {
#                 "actionGroup": action,
#                 "apiPath": api_path,
#                 "httpStatusCode": 200,
#                 "responseBody": {
#                     "application/json": {
#                         "body": json.dumps(order)
#                     }
#                 }
#             }
#         }
# ```
#
# ### Step 4: Invoke the Agent
# ```python
# bedrock_runtime = boto3.client('bedrock-agent-runtime')
#
# response = bedrock_runtime.invoke_agent(
#     agentId='AGENT_ID',
#     agentAliasId='ALIAS_ID',
#     sessionId='unique-session-123',
#     inputText='What is the status of order #12345?'
# )
#
# # Stream the response
# for event in response['completion']:
#     if 'chunk' in event:
#         print(event['chunk']['bytes'].decode())
# ```
#
# ---
#
# ## Agent Collaboration (Multi-Agent)
#
# Bedrock supports **multi-agent architectures**:
#
# ```
#                 ┌─────────────────┐
#                 │ Supervisor Agent │
#                 │  (Orchestrator)  │
#                 └────────┬────────┘
#                          │
#           ┌──────────────┼──────────────┐
#           │              │              │
#    ┌──────▼──────┐ ┌─────▼──────┐ ┌───▼────────┐
#    │  Research   │ │  Writing   │ │   Review   │
#    │   Agent     │ │   Agent    │ │   Agent    │
#    └─────────────┘ └────────────┘ └────────────┘
# ```
#
# ---
#
# ## Inline Agents
#
# Create **ephemeral agents on-the-fly** without pre-configuration:
#
# ```python
# response = bedrock_runtime.invoke_inline_agent(
#     foundationModel='anthropic.claude-3-sonnet-20240229-v1:0',
#     instruction='You are a data analysis assistant.',
#     actionGroups=[{
#         'actionGroupName': 'DataTools',
#         'actionGroupExecutor': {
#             'lambda': 'arn:aws:lambda:...'
#         }
#     }],
#     inputText='Analyze the sales data for Q4'
# )
# ```
#
# ---
#
# ## Built-in Capabilities
#
# | Capability | Description |
# |-----------|-------------|
# | **Code Interpreter** | Execute Python code dynamically |
# | **User Confirmation** | Pause and ask user before actions |
# | **Return of Control** | Send action back to your app to handle |
# | **Session Attributes** | Pass metadata throughout conversation |
#
# ---
#
# ## Common Use Cases
#
# | Use Case | Description |
# |----------|-------------|
# | **Customer Service** | Handle inquiries, orders, returns |
# | **IT Operations** | Automate incident response, ticketing |
# | **Data Analysis** | Query databases, generate reports |
# | **HR Assistant** | Answer policy questions, manage requests |
# | **DevOps Automation** | Deploy code, manage infrastructure |
# | **Research Assistant** | Gather, summarize, analyze information |
# | **Financial Analysis** | Process transactions, generate insights |
#
# ---
#
# ## Pricing Considerations
#
# ```
# Cost = FM Input Tokens + FM Output Tokens + AWS Service Calls
#
#        └── Per 1K tokens    └── Lambda, S3, OpenSearch, etc.
# ```
#
# - **No agent-specific fee** — pay for FM usage + underlying services
# - Knowledge Base adds **OpenSearch Serverless** or other vector DB costs
# - Lambda invocations billed normally
#
# ---
#
# ## Best Practices
#
# ### ✅ Do's
# - Write **clear, specific instructions** — quality matters greatly
# - **Break complex tasks** into smaller action groups
# - Use **guardrails** in production
# - **Test with diverse inputs** before deploying
# - Implement **proper error handling** in Lambda functions
# - Use **aliases** for versioning and deployment control
#
# ### ❌ Don'ts
# - Don't give agents **more permissions than needed** (least privilege)
# - Avoid **vague instructions** — be explicit about behavior
# - Don't skip **input validation** in your Lambda functions
# - Avoid exposing **sensitive data** without guardrails
#
# ---
#
# ## Comparison with Other Approaches
#
# | Feature | Bedrock Agents | DIY LangChain/LlamaIndex |
# |---------|---------------|--------------------------|
# | Setup | Managed, low-code | Custom code required |
# | Scaling | Automatic | Self-managed |
# | Maintenance | AWS managed | You manage |
# | Flexibility | Moderate | High |
# | Cost | Pay-per-use | Infrastructure costs |
# | Debugging | AWS Console + CloudWatch | Custom logging |
#
# ---
#
# ## Summary
#
# ```
# Amazon Bedrock Agents =
#     Foundation Model (Reasoning)
#     + Action Groups (Doing)
#     + Knowledge Bases (Knowing)
#     + Memory (Remembering)
#     + Guardrails (Safety)
#     = Autonomous AI Agent
# ```
#
# Bedrock Agents is ideal when you need AI that can **take actions**, not just generate text — automating complex workflows while staying within AWS's managed, secure environment.
