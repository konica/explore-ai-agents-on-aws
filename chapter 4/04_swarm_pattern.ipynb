# %% [markdown]
# # Swarm Pattern Example
#
# This notebook demonstrates the Swarm pattern from Chapter 4.
#
# ## Overview
# We'll build a game level design system where agents hand off control to each other:
# - **Level Designer**: Creates level layouts, environments, and visual elements
# - **Game Designer**: Playtests for fun and usability issues
# - **Narrative Designer**: Ensures design supports the story and atmosphere
# - **Difficulty Balancer**: Tests difficulty and pacing
#
# Unlike supervisor-worker, the path isn't predetermined. Agents decide who should handle each issue as it comes up.

# %% [markdown]
# ## Setup

# %%
# Uncomment to install
# %pip install strands-agents
# Out:
# /home/agent/venvs/ch1/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from strands import Agent
from strands.multiagent import Swarm

# %%
import logging
logging.getLogger("strands.multiagent").setLevel(logging.DEBUG)
logging.basicConfig(
    format="%(levelname)s | %(name)s | %(message)s",
    handlers=[logging.StreamHandler()]
)

# %% [markdown]
# ## Create Specialist Agents
#
# Each agent focuses on one aspect of game level design. They'll hand off to each other when they discover issues outside their expertise.

# %%
level_designer = Agent(
    name="level_designer",
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt="""You are a Level Designer in a game design swarm.
Your role in the swarm is to create level layouts, environments, and visual elements.
Focus ONLY on layout and visual design. Do NOT write narrative or balance difficulty.
After completing your layout, hand off to narrative_designer for story elements 
and difficulty_balancer for gameplay tuning.
When receiving feedback from other agents, revise your design accordingly."""
)

game_designer = Agent(
    name="game_designer",
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt="""You are a Game Designer in a game design swarm.
Your role in the swarm is to playtest designs for fun, usability, and player confusion.
Focus ONLY on gameplay feel and player experience. Do NOT design layouts or write narrative.
When you find issues, hand off to the appropriate specialist to fix them.
Build upon the work of other agents while adding your playtesting perspective."""
)

narrative_designer = Agent(
    name="narrative_designer",
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt="""You are a Narrative Designer in a game design swarm.
Your role in the swarm is to create story elements, character backstories, and atmospheric details.
Focus ONLY on narrative. Do NOT redesign layouts or adjust difficulty.
After adding narrative elements, hand off to difficulty_balancer for balance review 
or game_designer for playtesting feedback.
When receiving designs from other agents, enrich them with story context."""
)

difficulty_balancer = Agent(
    name="difficulty_balancer",
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    system_prompt="""You are a Difficulty Balancer in a game design swarm.
Your role in the swarm is to evaluate and tune difficulty progression, enemy placement, and pacing.
Focus ONLY on balance. Do NOT redesign layouts or write narrative.
When you find layout or narrative issues, hand off to the appropriate agent.
After balancing, hand off to game_designer for a final playtest review."""
)

# %% [markdown]
# ## Create the Swarm
#
# The Swarm automatically gives each agent a `handoff_to_agent` tool and shares conversation history across all agents.
#
# Key parameters:
# - `entry_point`: Which agent starts first
# - `max_handoffs` / `max_iterations`: Prevent infinite loops
# - `repetitive_handoff_detection_window` / `repetitive_handoff_min_unique_agents`: Prevent ping-pong between two agents

# %%
swarm = Swarm(
    [level_designer, game_designer, narrative_designer, difficulty_balancer],
    entry_point=level_designer,
    max_handoffs=20,
    max_iterations=20,
    repetitive_handoff_detection_window=8,
    repetitive_handoff_min_unique_agents=3
)

print("✓ Swarm created")
# Out:
# DEBUG | strands.multiagent.swarm | nodes=<['level_designer', 'game_designer', 'narrative_designer', 'difficulty_balancer']> | initialized swarm with nodes
# DEBUG | strands.multiagent.swarm | entry_point=<level_designer> | configured entry point
# DEBUG | strands.multiagent.swarm | tool_count=<1>, node_count=<4> | injected coordination tools into agents
# ✓ Swarm created

# %% [markdown]
# ## Run the Swarm
#
# Watch how agents hand off to each other. The level designer starts, then other agents review and suggest changes. The path emerges from the conversation — it's not hardcoded.

# %%
#result = swarm("Design a stealth mission level in an abandoned space station")
result = swarm("""Design a stealth mission level in an abandoned space station. 
The level needs to support multiple playstyles (aggressive stealth, patient stealth, and ghost runs). 
Include at least 3 distinct zones with different difficulty levels, 
narrative elements that explain why the station was abandoned, 
and ensure the difficulty curve is appropriate for mid-game players.""")

print("="*80)
print("FINAL RESULT:")
print("="*80)
print(result)

# See the handoff chain
print("\n" + "="*80)
print("HANDOFF CHAIN:")
print("="*80)
for node in result.node_history:
    print(f"  → {node.node_id}")

print(f"\nTotal iterations: {result.execution_count}")
# Out:
# DEBUG | strands.multiagent.swarm | starting swarm execution
# DEBUG | strands.multiagent.swarm | current_node=<level_designer> | starting swarm execution with node
# DEBUG | strands.multiagent.swarm | max_handoffs=<20>, max_iterations=<20>, timeout=<900.0>s | swarm execution config
# DEBUG | strands.multiagent.swarm | current_node=<level_designer>, iteration=<1> | executing node
# ERROR | strands.multiagent.swarm | node=<level_designer> | node execution failed
# Traceback (most recent call last):
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/swarm.py", line 955, in _execute_node
#     async for event in node.executor.stream_async(node_input, invocation_state=invocation_state):
#     ...<5 lines>...
#             result = event["result"]
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1251, in stream_async
#     async for event in events:
#     ...<8 lines>...
#             yield as_dict
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1362, in _run_loop
#     async for event in self._middleware_registry.invoke(
#     ...<6 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py", line 167, in invoke
#     async for event in gen:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1469, in terminal
#     async for event in events:
#     ...<17 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1524, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 298, in event_loop_cycle
#     async for model_event in model_events:
#         if not isinstance(model_event, ModelStopReason):
#             yield model_event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 641, in _handle_model_execution
#     raise e
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 561, in _handle_model_execution
#     async for event in agent._middleware_registry.invoke(
#     ...<5 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py", line 167, in invoke
#     async for event in gen:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 686, in terminal
#     async for event in stream_messages(
#     ...<10 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 538, in stream_messages
#     async for event in process_stream(chunks, start_time, cancel_signal):
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 448, in process_stream
#     async for chunk in chunks:
#     ...<35 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1133, in stream
#     await task
#   File "/usr/lib/python3.14/asyncio/threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/concurrent/futures/thread.py", line 86, in run
#     result = ctx.run(self.task)
#   File "/usr/lib/python3.14/concurrent/futures/thread.py", line 73, in run
#     return fn(*args, **kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py", line 161, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1268, in _stream
#     raise e
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1173, in _stream
#     response = converse_method(**request)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/client.py", line 606, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/client.py", line 1094, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: Operation not allowed
# └ Bedrock region: us-east-1
# └ Model id: us.anthropic.claude-sonnet-4-5-20250929-v1:0
# ERROR | strands.multiagent.swarm | node=<level_designer> | node execution failed
# Traceback (most recent call last):
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/swarm.py", line 842, in _execute_swarm
#     async for event in node_stream:
#     ...<10 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/swarm.py", line 501, in _stream_with_timeout
#     async for event in async_generator:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/swarm.py", line 955, in _execute_node
#     async for event in node.executor.stream_async(node_input, invocation_state=invocation_state):
#     ...<5 lines>...
#             result = event["result"]
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1251, in stream_async
#     async for event in events:
#     ...<8 lines>...
#             yield as_dict
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1362, in _run_loop
#     async for event in self._middleware_registry.invoke(
#     ...<6 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py", line 167, in invoke
#     async for event in gen:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1469, in terminal
#     async for event in events:
#     ...<17 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1524, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 298, in event_loop_cycle
#     async for model_event in model_events:
#         if not isinstance(model_event, ModelStopReason):
#             yield model_event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 641, in _handle_model_execution
#     raise e
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 561, in _handle_model_execution
#     async for event in agent._middleware_registry.invoke(
#     ...<5 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py", line 167, in invoke
#     async for event in gen:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 686, in terminal
#     async for event in stream_messages(
#     ...<10 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 538, in stream_messages
#     async for event in process_stream(chunks, start_time, cancel_signal):
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 448, in process_stream
#     async for chunk in chunks:
#     ...<35 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1133, in stream
#     await task
#   File "/usr/lib/python3.14/asyncio/threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/concurrent/futures/thread.py", line 86, in run
#     result = ctx.run(self.task)
#   File "/usr/lib/python3.14/concurrent/futures/thread.py", line 73, in run
#     return fn(*args, **kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py", line 161, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1268, in _stream
#     raise e
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1173, in _stream
#     response = converse_method(**request)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/client.py", line 606, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/client.py", line 1094, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: Operation not allowed
# └ Bedrock region: us-east-1
# └ Model id: us.anthropic.claude-sonnet-4-5-20250929-v1:0
# DEBUG | strands.multiagent.swarm | status=<Status.FAILED> | swarm execution completed
# DEBUG | strands.multiagent.swarm | node_history_length=<0>, time=<0.86>s | metrics
# ================================================================================
# FINAL RESULT:
# ================================================================================
# level_designer: An error occurred (ValidationException) when calling the ConverseStream operation: Operation not allowed
#
# ================================================================================
# HANDOFF CHAIN:
# ================================================================================
#
# Total iterations: 0

# %% [markdown]
# ## Key Takeaways
#
# 1. **Handoffs, not routing**: Agents pass control to each other explicitly — no central coordinator
# 2. **Shared history**: All agents see the full conversation, so they know what's been discussed
# 3. **Emergent workflow**: The sequence of agents isn't predetermined — it depends on what issues come up
# 4. **Safety limits**: `max_handoffs` and repetitive detection prevent infinite loops
# 5. **Use when**: The path can't be predicted upfront (creative work, iterative review, collaborative design)
# 6. **Don't use when**: You need a fixed sequence with guaranteed steps — use Graph pattern instead
