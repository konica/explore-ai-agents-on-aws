# %% [markdown]
# # Graph Pattern Example
#
# This notebook demonstrates the Graph pattern from Chapter 4.
#
# ## Overview
# We'll build an e-commerce order processing pipeline where orders follow explicit, auditable paths:
# - **Risk Analyzer**: Categorizes orders by risk level
# - **Manual Review Agent**: Reviews high-value orders
# - **Fraud Detection Agent**: Checks suspicious orders
# - **Inventory Agent**: Checks stock availability
# - **Shipping Agent**: Processes shipments
# - **Refund Agent**: Handles out-of-stock refunds
#
# Unlike Swarm, the routing is explicit in code — every path is visible and auditable.

# %% [markdown]
# ## Setup

# %%
# Uncomment to install
# %pip install strands-agents
# Out:
# /home/agent/venvs/ch1/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from strands import Agent
from strands.multiagent import GraphBuilder

# %% [markdown]
# ## Create Specialized Agents
#
# Each agent handles one step in the order processing pipeline.

# %%
risk_analyzer = Agent(
    name="risk_analyzer",
    system_prompt="""Analyze order risk level. Categorize each order as:
    - HIGH_VALUE: Orders over $1,000
    - SUSPICIOUS: Mismatched billing/shipping address, new account with large order, or known fraud patterns
    - LOW_RISK: Regular orders from trusted customers
    Always include the risk category in your response."""
)

manual_review_agent = Agent(
    name="manual_review_agent",
    system_prompt="Review high-value orders. Verify customer identity, check order history, and approve or flag for further review."
)

fraud_detection_agent = Agent(
    name="fraud_detection_agent",
    system_prompt="Run advanced fraud detection on suspicious orders. Check for known fraud patterns, velocity checks, and device fingerprinting."
)

inventory_agent = Agent(
    name="inventory_agent",
    system_prompt="""Check inventory availability for the order items. Respond with:
    - IN_STOCK: All items available
    - OUT_OF_STOCK: One or more items unavailable
    Always include the stock status in your response."""
)

shipping_agent = Agent(
    name="shipping_agent",
    system_prompt="Generate shipping labels and process the shipment. Confirm tracking number and estimated delivery date."
)

refund_agent = Agent(
    name="refund_agent",
    system_prompt="Process refund for out-of-stock items. Notify the customer and initiate payment reversal."
)

print("✓ All agents created")
# Out:
# ✓ All agents created

# %% [markdown]
# ## Define Routing Conditions
#
# These functions check the output from previous nodes to decide which path to follow. The logic is explicit in code — not hidden in LLM reasoning.

# %%
def is_high_value(state):
    """Route to manual review if order is high value."""
    result = str(state.results.get("risk_analysis", "")).upper()
    return "HIGH_VALUE" in result

def is_suspicious(state):
    """Route to fraud detection if order is suspicious."""
    result = str(state.results.get("risk_analysis", "")).upper()
    return "SUSPICIOUS" in result

def is_low_risk(state):
    """Route directly to inventory if order is low risk."""
    result = str(state.results.get("risk_analysis", "")).upper()
    return "LOW_RISK" in result

def is_in_stock(state):
    """Route to shipping if items are in stock."""
    result = str(state.results.get("inventory_check", "")).upper()
    return "IN_STOCK" in result

def is_out_of_stock(state):
    """Route to refund if items are out of stock."""
    result = str(state.results.get("inventory_check", "")).upper()
    return "OUT_OF_STOCK" in result

print("✓ Routing conditions defined")
# Out:
# ✓ Routing conditions defined

# %% [markdown]
# ## Build the Graph
#
# Add agents as nodes, then connect them with edges. Conditional edges route orders based on risk level and stock availability.
#
# ```
#                     ┌─ HIGH_VALUE ──→ Manual Review ─┐
# Risk Analyzer ──────┼─ SUSPICIOUS ──→ Fraud Check ───┼──→ Inventory ──┬─ IN_STOCK ────→ Shipping
#                     └─ LOW_RISK ─────────────────────┘               └─ OUT_OF_STOCK ─→ Refund
# ```

# %%
builder = GraphBuilder()

# Add nodes
builder.add_node(risk_analyzer, "risk_analysis")
builder.add_node(manual_review_agent, "manual_review")
builder.add_node(fraud_detection_agent, "fraud_check")
builder.add_node(inventory_agent, "inventory_check")
builder.add_node(shipping_agent, "shipping")
builder.add_node(refund_agent, "refund")

# Add conditional edges from risk analysis
builder.add_edge("risk_analysis", "manual_review", condition=is_high_value)
builder.add_edge("risk_analysis", "fraud_check", condition=is_suspicious)
builder.add_edge("risk_analysis", "inventory_check", condition=is_low_risk)

# After review/fraud check, proceed to inventory
builder.add_edge("manual_review", "inventory_check")
builder.add_edge("fraud_check", "inventory_check")

# After inventory, ship or refund
builder.add_edge("inventory_check", "shipping", condition=is_in_stock)
builder.add_edge("inventory_check", "refund", condition=is_out_of_stock)

# Set entry point and build
builder.set_entry_point("risk_analysis")
graph = builder.build()

print("✓ Graph built")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ✓ Graph built

# %% [markdown]
# ## Process Orders
#
# Each order follows a different path through the graph based on its risk level.

# %%
# High-value order → manual review → inventory → shipping
print("Order 1: High-value order")
print("="*80)
result = graph("Order #12345: $1,500 laptop from new customer, billing and shipping address match")
print(result)
# Out:
# Order 1: High-value order
# ================================================================================
# node_id=<risk_analysis>, error=<An error occurred (ValidationException) when calling the ConverseStream operation: Operation not allowed> | node failed
# graph execution failed
# Traceback (most recent call last):
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py", line 677, in stream_async
#     async for event in self._execute_graph(invocation_state):
#     ...<3 lines>...
#         yield event.as_dict()
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py", line 788, in _execute_graph
#     async for event in self._execute_nodes_parallel(current_batch, invocation_state):
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py", line 864, in _execute_nodes_parallel
#     raise event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py", line 902, in _stream_node_to_queue
#     async for event in self._execute_node(node, invocation_state):
#         await event_queue.put(event)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py", line 1042, in _execute_node
#     async for event in node.executor.stream_async(node_input, invocation_state=invocation_state):
#     ...<5 lines>...
#             agent_response = event["result"]
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1251, in stream_async
#     async for event in events:
#     ...<8 lines>...
#             yield as_dict
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1362, in _run_loop
#     async for event in self._middleware_registry.invoke(
#     ...<6 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py", line 167, in invoke
#     async for event in gen:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1469, in terminal
#     async for event in events:
#     ...<17 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py", line 1524, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 298, in event_loop_cycle
#     async for model_event in model_events:
#         if not isinstance(model_event, ModelStopReason):
#             yield model_event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 641, in _handle_model_execution
#     raise e
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 561, in _handle_model_execution
#     async for event in agent._middleware_registry.invoke(
#     ...<5 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py", line 167, in invoke
#     async for event in gen:
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 686, in terminal
#     async for event in stream_messages(
#     ...<10 lines>...
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 538, in stream_messages
#     async for event in process_stream(chunks, start_time, cancel_signal):
#         yield event
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 448, in process_stream
#     async for chunk in chunks:
#     ...<35 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1133, in stream
#     await task
#   File "/usr/lib/python3.14/asyncio/threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/concurrent/futures/thread.py", line 86, in run
#     result = ctx.run(self.task)
#   File "/usr/lib/python3.14/concurrent/futures/thread.py", line 73, in run
#     return fn(*args, **kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py", line 161, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1268, in _stream
#     raise e
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py", line 1173, in _stream
#     response = converse_method(**request)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/client.py", line 606, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/agent/venvs/ch1/lib/python3.14/site-packages/botocore/client.py", line 1094, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: Operation not allowed
# └ Bedrock region: us-east-1
# └ Model id: global.anthropic.claude-sonnet-4-6
# ---------------------------------------------------------------------------
# ValidationException                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 # High-value order → manual review → inventory → shipping
#       2 print("Order 1: High-value order")
#       3 print("="*80)
# ----> 4 result = graph("Order #12345: $1,500 laptop from new customer, billing and shipping address match")
#       5 print(result)
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py:592, in Graph.__call__(self, task, invocation_state, **kwargs)
#     589 if invocation_state is None:
#     590     invocation_state = {}
# --> 592 return run_async(lambda: self.invoke_async(task, invocation_state))
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/_async.py:34, in run_async(async_func)
#      32 context = contextvars.copy_context()
#      33 future = executor.submit(context.run, execute)
# ---> 34 return future.result()
#
# File /usr/lib/python3.14/concurrent/futures/_base.py:450, in Future.result(self, timeout)
#     448     raise CancelledError()
#     449 elif self._state == FINISHED:
# --> 450     return self.__get_result()
#     451 else:
#     452     raise TimeoutError()
#
# File /usr/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /usr/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File /usr/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File ~/venvs/ch1/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py:161, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     159 try:
#     160     token = context.attach(otel_context)
# --> 161     return original_func(*func_args, **func_kwargs)
#     162 finally:
#     163     if token is not None:
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/_async.py:29, in run_async.<locals>.execute()
#      28 def execute() -> T:
# ---> 29     return asyncio.run(execute_async())
#
# File /usr/lib/python3.14/asyncio/runners.py:204, in run(main, debug, loop_factory)
#     200     raise RuntimeError(
#     201         "asyncio.run() cannot be called from a running event loop")
#     203 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 204     return runner.run(main)
#
# File /usr/lib/python3.14/asyncio/runners.py:127, in Runner.run(self, coro, context)
#     125 self._interrupt_count = 0
#     126 try:
# --> 127     return self._loop.run_until_complete(task)
#     128 except exceptions.CancelledError:
#     129     if self._interrupt_count > 0:
#
# File /usr/lib/python3.14/asyncio/base_events.py:719, in BaseEventLoop.run_until_complete(self, future)
#     716 if not future.done():
#     717     raise RuntimeError('Event loop stopped before Future completed.')
# --> 719 return future.result()
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/_async.py:26, in run_async.<locals>.execute_async()
#      25 async def execute_async() -> T:
# ---> 26     return await async_func()
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py:610, in Graph.invoke_async(self, task, invocation_state, **kwargs)
#     608 events = self.stream_async(task, invocation_state, **kwargs)
#     609 final_event = None
# --> 610 async for event in events:
#     611     final_event = event
#     613 if final_event is None or "result" not in final_event:
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py:677, in Graph.stream_async(self, task, invocation_state, **kwargs)
#     669 try:
#     670     logger.debug(
#     671         "max_node_executions=<%s>, execution_timeout=<%s>s, node_timeout=<%s>s | graph execution config",
#     672         self.max_node_executions or "None",
#     673         self.execution_timeout or "None",
#     674         self.node_timeout or "None",
#     675     )
# --> 677     async for event in self._execute_graph(invocation_state):
#     678         if isinstance(event, MultiAgentNodeInterruptEvent):
#     679             interrupts.extend(event.interrupts)
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py:788, in Graph._execute_graph(self, invocation_state)
#     785 ready_nodes.clear()
#     787 # Execute current batch
# --> 788 async for event in self._execute_nodes_parallel(current_batch, invocation_state):
#     789     yield event
#     791 if self.state.status == Status.INTERRUPTED:
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py:864, in Graph._execute_nodes_parallel(self, nodes, invocation_state)
#     862 event = await event_queue.get()
#     863 if isinstance(event, Exception):
# --> 864     raise event
#     865 if event is not None:
#     866     yield event
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py:902, in Graph._stream_node_to_queue(self, node, event_queue, invocation_state)
#     899             await event_queue.put(timeout_exc)
#     900     else:
#     901         # No timeout - stream normally
# --> 902         async for event in self._execute_node(node, invocation_state):
#     903             await event_queue.put(event)
#     904 except Exception as e:
#     905     # Send exception through queue for fail-fast behavior
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/multiagent/graph.py:1042, in Graph._execute_node(self, node, invocation_state)
#    1039 elif isinstance(node.executor, AgentBase):
#    1040     # For AgentBase implementations (Agent, A2AAgent, etc.), stream events and collect result
#    1041     agent_response = None
# -> 1042     async for event in node.executor.stream_async(node_input, invocation_state=invocation_state):
#    1043         # Forward agent events with node context
#    1044         wrapped_event = MultiAgentNodeStreamEvent(node.node_id, event)
#    1045         yield wrapped_event
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py:1251, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, structured_output_prompt, idempotency_token, limits, **kwargs)
#    1248 # The result is the last EventLoopStopEvent, not the last event overall:
#    1249 # AgentStreamStage middleware may yield trailing events after the stop event.
#    1250 stop_event: EventLoopStopEvent | None = None
# -> 1251 async for event in events:
#    1252     event.prepare(invocation_state=merged_state)
#    1254     if isinstance(event, EventLoopStopEvent):
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py:1362, in Agent._run_loop(self, messages, invocation_state, structured_output_model, structured_output_prompt, limits)
#    1352 middleware_context = AgentStreamContext(
#    1353     agent=self,
#    1354     messages=current_messages,
#    (...)   1359     _interrupts=dict(self._interrupt_state.interrupts) if self._interrupt_state.activated else {},
#    1360 )
#    1361 try:
# -> 1362     async for event in self._middleware_registry.invoke(
#    1363         AgentStreamStage,
#    1364         middleware_context,
#    1365         self._make_agent_stream_terminal(structured_output_context, limits, pass_progress),
#    1366     ):
#    1367         if isinstance(event, EventLoopStopEvent):
#    1368             agent_result = AgentResult(*event["stop"])
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py:167, in MiddlewareRegistry.invoke(self, stage, context, terminal)
#     165 gen = chain(context)
#     166 try:
# --> 167     async for event in gen:
#     168         yield event
#     169 finally:
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py:1469, in Agent._make_agent_stream_terminal.<locals>.terminal(ctx)
#    1466 async def terminal(ctx: "AgentStreamContext") -> AsyncGenerator[TypedEvent, None]:
#    1467     # Execute the event loop cycle with retry logic for context limits
#    1468     events = self._execute_event_loop_cycle(ctx.invocation_state, structured_output_context, limits)
# -> 1469     async for event in events:
#    1470         if isinstance(event, EventLoopStopEvent):
#    1471             pass_progress.event_loop_produced_result = True
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/agent/agent.py:1524, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context, limits)
#    1517 try:
#    1518     events = event_loop_cycle(
#    1519         agent=self,
#    1520         invocation_state=invocation_state,
#    1521         structured_output_context=structured_output_context,
#    1522         limits=limits,
#    1523     )
# -> 1524     async for event in events:
#    1525         yield event
#    1527 except ContextWindowOverflowException as e:
#    1528     # Try reducing the context size and retrying
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py:298, in event_loop_cycle(agent, invocation_state, structured_output_context, limits)
#     294 else:
#     295     model_events = _handle_model_execution(
#     296         agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     297     )
# --> 298     async for model_event in model_events:
#     299         if not isinstance(model_event, ModelStopReason):
#     300             yield model_event
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py:641, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     639         # No retry requested, raise the exception
#     640         yield ForceStopEvent(reason=e)
# --> 641         raise e
#     643 try:
#     644     # Add message in trace and mark the end of the stream messages trace
#     645     stream_trace.add_message(message)
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py:561, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     558 # Run through middleware chain. The last yielded event is ModelStopReason
#     559 # which serves as both the streaming result event and the middleware result.
#     560 last_event = None
# --> 561 async for event in agent._middleware_registry.invoke(
#     562     InvokeModelStage,
#     563     middleware_context,
#     564     _make_invoke_model_terminal(agent, cycle_span, tracer, model_state_snapshot),
#     565 ):
#     566     last_event = event
#     567     yield event
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/_middleware/registry.py:167, in MiddlewareRegistry.invoke(self, stage, context, terminal)
#     165 gen = chain(context)
#     166 try:
# --> 167     async for event in gen:
#     168         yield event
#     169 finally:
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/event_loop.py:686, in _make_invoke_model_terminal.<locals>.terminal(ctx)
#     684 with trace_api.use_span(model_invoke_span, end_on_exit=False):
#     685     try:
# --> 686         async for event in stream_messages(
#     687             ctx.model,
#     688             system_prompt_str,
#     689             ctx.messages,
#     690             ctx.tool_specs,
#     691             system_prompt_content=system_prompt_content,
#     692             tool_choice=ctx.tool_choice,
#     693             invocation_state=ctx.invocation_state,
#     694             model_state=model_state,
#     695             cancel_signal=agent._cancel_signal,
#     696         ):
#     697             yield event
#     699         stop_reason, message, usage, metrics = event["stop"]
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py:538, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice, system_prompt_content, invocation_state, model_state, cancel_signal, **kwargs)
#     526 start_time = time.time()
#     528 chunks = model.stream(
#     529     messages,
#     530     tool_specs if tool_specs else None,
#    (...)    535     model_state=model_state,
#     536 )
# --> 538 async for event in process_stream(chunks, start_time, cancel_signal):
#     539     yield event
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/event_loop/streaming.py:448, in process_stream(chunks, start_time, cancel_signal)
#     445 usage: Usage = Usage(inputTokens=0, outputTokens=0, totalTokens=0)
#     446 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 448 async for chunk in chunks:
#     449     # Check for cancellation during stream processing
#     450     if cancel_signal and cancel_signal.is_set():
#     451         logger.debug("cancellation detected during stream processing")
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py:1133, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, system_prompt_content, **kwargs)
#    1130             break
#    1132         yield event
# -> 1133     await task
#    1134 except BaseException:
#    1135     task.add_done_callback(_suppress_task_exception)
#
# File /usr/lib/python3.14/asyncio/threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File /usr/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File /usr/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File ~/venvs/ch1/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py:161, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     159 try:
#     160     token = context.attach(otel_context)
# --> 161     return original_func(*func_args, **func_kwargs)
#     162 finally:
#     163     if token is not None:
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py:1268, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#    1258     if (
#    1259         e.response["Error"]["Code"] == "ValidationException"
#    1260         and "with on-demand throughput isn’t supported" in error_message
#    1261     ):
#    1262         add_exception_note(
#    1263             e,
#    1264             "└ For more information see "
#    1265             "https://strandsagents.com/docs/user-guide/concepts/model-providers/amazon-bedrock/#on-demand-throughput-isnt-supported",
#    1266         )
# -> 1268     raise e
#    1270 finally:
#    1271     callback()
#
# File ~/venvs/ch1/lib/python3.14/site-packages/strands/models/bedrock.py:1173, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#    1170 converse_method = self.client.converse_stream if streaming else self.client.converse
#    1172 try:
# -> 1173     response = converse_method(**request)
#    1174 except ClientError as error:
#    1175     error_details = error.response.get("Error", {})
#
# File ~/venvs/ch1/lib/python3.14/site-packages/botocore/client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File ~/venvs/ch1/lib/python3.14/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/venvs/ch1/lib/python3.14/site-packages/botocore/client.py:1094, in BaseClient._make_api_call(self, operation_name, api_params)
#    1090     error_code = request_context.get(
#    1091         'error_code_override'
#    1092     ) or error_info.get("Code")
#    1093     error_class = self.exceptions.from_code(error_code)
# -> 1094     raise error_class(parsed_response, operation_name)
#    1095 else:
#    1096     return parsed_response
#
# ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: Operation not allowed
# └ Bedrock region: us-east-1
# └ Model id: global.anthropic.claude-sonnet-4-6

# %%
# Low-risk order → straight to inventory → shipping
print("Order 2: Low-risk order")
print("="*80)
result = graph("Order #67890: $45 book from returning customer with 50+ previous orders")
print(result)

# %%
# Suspicious order → fraud check → inventory → shipping/refund
print("Order 3: Suspicious order")
print("="*80)
result = graph("Order #11111: $800 electronics, new account created 5 minutes ago, shipping to different country than billing")
print(result)

# %% [markdown]
# ## Key Takeaways
#
# 1. **Explicit routing**: Every path is visible in code — not hidden in LLM reasoning
# 2. **Auditable**: If someone asks "how do you handle fraud?", point to the graph structure
# 3. **Directed Acyclic Graph**: Arrows only point forward, no loops — every order reaches an end state
# 4. **Conditional edges**: Route based on data, not LLM interpretation
# 5. **Use when**: You have established procedures (compliance, approval chains, order processing)
# 6. **Don't use when**: The path can't be predicted upfront — use Swarm instead
